# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("reading_data/IMDB_Top250.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0                                          Title  Year     Rated  \
# 0           1                       The Shawshank Redemption  1994         R
# 1           2                                  The Godfather  1972         R
# 2           3                         The Godfather: Part II  1974         R
# 3           4                                The Dark Knight  2008     PG-13
# 4           5                                   12 Angry Men  1957  APPROVED
# 5           6                               Schindler's List  1993         R
# 6           7                                   Pulp Fiction  1994         R
# 7           8  The Lord of the Rings: The Return of the King  2003     PG-13
# 8           9                 The Good, the Bad and the Ugly  1966  APPROVED
# 9          10                                     Fight Club  1999         R
#
#       Released  Runtime                      Genre              Director  \
# ...

# %%
df.tail(10)
# Out:
#      Unnamed: 0                                              Title  Year  \
# 240         241                                           The Help  2011
# 241         242                               Beauty and the Beast  1991
# 242         243                                  Dog Day Afternoon  1975
# 243         244                              The Battle of Algiers  1966
# 244         245                               In the Mood for Love  2000
# 245         246  Pirates of the Caribbean: The Curse of the Bla...  2003
# 246         247                   What Ever Happened to Baby Jane?  1962
# 247         248                                       Paris, Texas  1984
# 248         249                                           Drishyam  2015
# 249         250                                                 PK  2014
#
#          Rated     Released  Runtime                       Genre  \
# 240      PG-13  10 Aug 2011  146 min                       Drama
# ...

# %%
df["Title"]
# Out:
# 0                               The Shawshank Redemption
# 1                                          The Godfather
# 2                                 The Godfather: Part II
# 3                                        The Dark Knight
# 4                                           12 Angry Men
#                              ...
# 245    Pirates of the Caribbean: The Curse of the Bla...
# 246                     What Ever Happened to Baby Jane?
# 247                                         Paris, Texas
# 248                                             Drishyam
# 249                                                   PK
# Name: Title, Length: 250, dtype: object

# %%
df["Title"].head(10)
# Out:
# 0                         The Shawshank Redemption
# 1                                    The Godfather
# 2                           The Godfather: Part II
# 3                                  The Dark Knight
# 4                                     12 Angry Men
# 5                                 Schindler's List
# 6                                     Pulp Fiction
# 7    The Lord of the Rings: The Return of the King
# 8                   The Good, the Bad and the Ugly
# 9                                       Fight Club
# Name: Title, dtype: object

# %%
df["Title"].tail(10)
# Out:
# 240                                             The Help
# 241                                 Beauty and the Beast
# 242                                    Dog Day Afternoon
# 243                                The Battle of Algiers
# 244                                 In the Mood for Love
# 245    Pirates of the Caribbean: The Curse of the Bla...
# 246                     What Ever Happened to Baby Jane?
# 247                                         Paris, Texas
# 248                                             Drishyam
# 249                                                   PK
# Name: Title, dtype: object

# %%
df[["Title","imdbRating"]].head(10)
# Out:
#                                            Title  imdbRating
# 0                       The Shawshank Redemption         9.3
# 1                                  The Godfather         9.2
# 2                         The Godfather: Part II         9.0
# 3                                The Dark Knight         9.0
# 4                                   12 Angry Men         8.9
# 5                               Schindler's List         8.9
# 6                                   Pulp Fiction         8.9
# 7  The Lord of the Rings: The Return of the King         8.9
# 8                 The Good, the Bad and the Ugly         8.9
# 9                                     Fight Club         8.8

# %%
df[["Title","imdbRating"]].tail(10)
# Out:
#                                                  Title  imdbRating
# 240                                           The Help         8.1
# 241                               Beauty and the Beast         8.0
# 242                                  Dog Day Afternoon         8.0
# 243                              The Battle of Algiers         8.1
# 244                               In the Mood for Love         8.1
# 245  Pirates of the Caribbean: The Curse of the Bla...         8.0
# 246                   What Ever Happened to Baby Jane?         8.1
# 247                                       Paris, Texas         8.1
# 248                                           Drishyam         8.4
# 249                                                 PK         8.2

# %%
df[(df["imdbRating"] >= 8.8)] [["Title", "imdbRating"]]
# Out:
#                                                 Title  imdbRating
# 0                            The Shawshank Redemption         9.3
# 1                                       The Godfather         9.2
# 2                              The Godfather: Part II         9.0
# 3                                     The Dark Knight         9.0
# 4                                        12 Angry Men         8.9
# 5                                    Schindler's List         8.9
# 6                                        Pulp Fiction         8.9
# 7       The Lord of the Rings: The Return of the King         8.9
# 8                      The Good, the Bad and the Ugly         8.9
# 9                                          Fight Club         8.8
# 10  The Lord of the Rings: The Fellowship of the Ring         8.8
# 11                                       Forrest Gump         8.8
# 12     Star Wars: Episode V - The Empire Strikes Back         8.8
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Year', 'Rated', 'Released', 'Runtime', 'Genre',
#        'Director', 'Writer', 'Actors', 'Plot', 'Language', 'Country', 'Awards',
#        'Poster', 'Ratings.Source', 'Ratings.Value', 'Metascore', 'imdbRating',
#        'imdbVotes', 'imdbID', 'Type', 'tomatoMeter', 'tomatoImage',
#        'tomatoRating', 'tomatoReviews', 'tomatoFresh', 'tomatoRotten',
#        'tomatoConsensus', 'tomatoUserMeter', 'tomatoUserRating',
#        'tomatoUserReviews', 'tomatoURL', 'DVD', 'BoxOffice', 'Production',
#        'Website', 'Response'],
#       dtype='object')

# %%
df[(df["imdbRating"] > 8.5) & (df["Year"] >= 2005)] [["Title","imdbRating","Year"]]
# Out:
#                     Title  imdbRating  Year
# 3         The Dark Knight         9.0  2008
# 13              Inception         8.8  2010
# 31           Interstellar         8.6  2014
# 36       The Intouchables         8.6  2011
# 70                 Dangal         8.7  2016
# 91              Your Name         8.6  2016
# 105  My Father and My Son         8.6  2005

# %%
df[(df["Year"] >= 2000) & (df["Year"] <= 2005) & (df["imdbRating"] > 8.5)] [["Title", "imdbRating", "Year"]]
# Out:
#                                                  Title  imdbRating  Year
# 7        The Lord of the Rings: The Return of the King         8.9  2003
# 10   The Lord of the Rings: The Fellowship of the Ring         8.8  2001
# 14               The Lord of the Rings: The Two Towers         8.7  2002
# 20                                         City of God         8.7  2002
# 28                                       Spirited Away         8.6  2001
# 105                               My Father and My Son         8.6  2005

# %%
df[(df["Year"] >= 2000) & (df["Year"] <= 2005)].mean()
# Out:
# Unnamed: 0            132.969697
# Year                 2002.181818
# Metascore              78.466667
# imdbRating              8.315152
# tomatoMeter                  NaN
# tomatoImage                  NaN
# tomatoRating                 NaN
# tomatoReviews                NaN
# tomatoFresh                  NaN
# tomatoRotten                 NaN
# tomatoConsensus              NaN
# tomatoUserMeter              NaN
# tomatoUserRating             NaN
# tomatoUserReviews            NaN
# Response                1.000000
# dtype: float64

# %%
df["imdbRating"].mean()
# Out:
# 8.320399999999976

# %%
df.describe().T
# Out:
#                    count         mean        std     min      25%     50%  \
# Unnamed: 0         250.0   125.500000  72.312977     1.0    63.25   125.5
# Year               250.0  1984.652000  24.158506  1921.0  1966.00  1992.5
# Metascore          173.0    81.023121  11.050599    53.0    74.00    82.0
# imdbRating         250.0     8.320400   0.229946     8.0     8.10     8.3
# tomatoMeter          0.0          NaN        NaN     NaN      NaN     NaN
# tomatoImage          0.0          NaN        NaN     NaN      NaN     NaN
# tomatoRating         0.0          NaN        NaN     NaN      NaN     NaN
# tomatoReviews        0.0          NaN        NaN     NaN      NaN     NaN
# tomatoFresh          0.0          NaN        NaN     NaN      NaN     NaN
# tomatoRotten         0.0          NaN        NaN     NaN      NaN     NaN
# tomatoConsensus      0.0          NaN        NaN     NaN      NaN     NaN
# tomatoUserMeter      0.0          NaN        NaN     NaN      NaN     NaN
# ...

# %%
x = df.groupby("Year").get_group(2016)
x
# Out:
#      Unnamed: 0          Title  Year    Rated     Released  Runtime  \
# 70           71         Dangal  2016  UNRATED  21 Dec 2016  161 min
# 91           92      Your Name  2016       PG  07 Apr 2017  106 min
# 139         140     La La Land  2016    PG-13  25 Dec 2016  128 min
# 161         162  Hacksaw Ridge  2016        R  04 Nov 2016  139 min
#
#                          Genre         Director  \
# 70    Action, Biography, Drama    Nitesh Tiwari
# 91   Animation, Drama, Fantasy   Makoto Shinkai
# 139       Comedy, Drama, Music  Damien Chazelle
# 161  Biography, Drama, History       Mel Gibson
#
#                                                 Writer  \
# 70   Piyush Gupta, Shreyas Jain, Nikhil Mehrotra, N...
# 91   Makoto Shinkai (based on his novel), Makoto Sh...
# 139                                    Damien Chazelle
# 161  Robert Schenkkan (screenplay), Andrew Knight (...
#
#                                                 Actors  ... tomatoConsensus  \
# ...

# %%
y = df.groupby("Year").get_group(2017)
y
# Out:
#      Unnamed: 0        Title  Year Rated     Released  Runtime  \
# 129         130  Baby Driver  2017     R  28 Jun 2017  113 min
# 147         148        Logan  2017     R  03 Mar 2017  137 min
#
#                      Genre       Director  \
# 129   Action, Crime, Music   Edgar Wright
# 147  Action, Drama, Sci-Fi  James Mangold
#
#                                                 Writer  \
# 129                                       Edgar Wright
# 147  James Mangold (story by), Scott Frank (screenp...
#
#                                                 Actors  ... tomatoConsensus  \
# 129  Ansel Elgort, Jon Bernthal, Jon Hamm, Eiza Gon...  ...             NaN
# 147  Hugh Jackman, Patrick Stewart, Dafne Keen, Boy...  ...             NaN
#
#     tomatoUserMeter tomatoUserRating tomatoUserReviews  \
# 129             NaN              NaN               NaN
# 147             NaN              NaN               NaN
#
# ...

# %%
pd.concat([x, y])
# Out:
#      Unnamed: 0          Title  Year    Rated     Released  Runtime  \
# 70           71         Dangal  2016  UNRATED  21 Dec 2016  161 min
# 91           92      Your Name  2016       PG  07 Apr 2017  106 min
# 139         140     La La Land  2016    PG-13  25 Dec 2016  128 min
# 161         162  Hacksaw Ridge  2016        R  04 Nov 2016  139 min
# 129         130    Baby Driver  2017        R  28 Jun 2017  113 min
# 147         148          Logan  2017        R  03 Mar 2017  137 min
#
#                          Genre         Director  \
# 70    Action, Biography, Drama    Nitesh Tiwari
# 91   Animation, Drama, Fantasy   Makoto Shinkai
# 139       Comedy, Drama, Music  Damien Chazelle
# 161  Biography, Drama, History       Mel Gibson
# 129       Action, Crime, Music     Edgar Wright
# 147      Action, Drama, Sci-Fi    James Mangold
#
#                                                 Writer  \
# 70   Piyush Gupta, Shreyas Jain, Nikhil Mehrotra, N...
# ...

# %%
df.groupby("Year").mean()
# Out:
#       Unnamed: 0  Metascore  imdbRating  tomatoMeter  tomatoImage  \
# Year
# 1921   96.000000        NaN    8.300000          NaN          NaN
# 1925  133.000000        NaN    8.200000          NaN          NaN
# 1926  153.000000        NaN    8.200000          NaN          NaN
# 1927  134.000000       98.0    8.300000          NaN          NaN
# 1928  172.000000        NaN    8.300000          NaN          NaN
# ...          ...        ...         ...          ...          ...
# 2013  190.500000       80.0    8.125000          NaN          NaN
# 2014  148.500000       81.2    8.266667          NaN          NaN
# 2015  187.666667       88.8    8.183333          NaN          NaN
# 2016  116.250000       81.0    8.425000          NaN          NaN
# 2017  139.000000       80.0    8.400000          NaN          NaN
#
#       tomatoRating  tomatoReviews  tomatoFresh  tomatoRotten  tomatoConsensus  \
# Year
# 1921           NaN            NaN          NaN           NaN              NaN
# ...

# %%
df["Year"].mean()
# Out:
# 1984.652

# %%
df.notnull()
# Out:
#      Unnamed: 0  Title  Year  Rated  Released  Runtime  Genre  Director  \
# 0          True   True  True   True      True     True   True      True
# 1          True   True  True   True      True     True   True      True
# 2          True   True  True   True      True     True   True      True
# 3          True   True  True   True      True     True   True      True
# 4          True   True  True   True      True     True   True      True
# ..          ...    ...   ...    ...       ...      ...    ...       ...
# 245        True   True  True   True      True     True   True      True
# 246        True   True  True   True     False     True   True      True
# 247        True   True  True   True      True     True   True      True
# 248        True   True  True   True      True     True   True      True
# 249        True   True  True  False      True     True   True      True
#
#      Writer  Actors  ...  tomatoConsensus  tomatoUserMeter  tomatoUserRating  \
# ...
